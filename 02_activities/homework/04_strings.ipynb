# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here
print("This is in the first line\nThis is in the second line")
# Out:
# This is in the first line
# This is in the second line

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here

# %% [markdown]
# Palindrome

# %%
# Your code goes here

### 3. Write a function to check if a string is a palindrome
# Your code goes here
def isPalindrome(str):
    return str==str[::-1]

print(isPalindrome("saias"))
# Out:
# True
